# %%
# load libraries

import numpy as np
import pandas as pd
from tqdm import tqdm

# my own custom functions
import EDA_functions as EDA
import cleaning_functions as cleaning

# visualization
import matplotlib.pyplot as plt
import seaborn as sns #, sns.set_style('whitegrid')
color = 'rebeccapurple'
# %matplotlib inline

# display settings
from IPython.display import display
pd.options.display.max_columns = None

from pathlib import Path  # to make file path references relative to notebook directory

# %%
# import data

transcript_extended_hardcopy = Path.cwd() / "data" / "interim" / "transcript_extended.csv"
transcript_flagged_hardcopy = Path.cwd() / "data" / "interim" / "transcript_flagged.csv"
portfolio_file = Path.cwd() / "data" / "processed" / "portfolio_clean.csv"

# load 
transcript = pd.read_csv(transcript_extended_hardcopy)
transcript_flagged = pd.read_csv(transcript_flagged_hardcopy)
portfolio = pd.read_csv(portfolio_file, index_col = 0)

# %% [markdown]
# ---

# %%
"""create sample dataframe with events of three random customers"""

transcript_sample = transcript.loc[transcript['person_id'].isin(['p_1', 'p_2', 'p_3', 'p_200', 'p_10126', 'p_10', 'p_101', 'p_4'])]
transcript_sample = transcript_sample.sort_values(['person_id', 'time']).reset_index(drop=True)
display(transcript_sample.head())
# Out:
#             event person_id  time  amount offer_id  o_1  o_2  o_3  o_4  o_5  \
# 0  offer received       p_1   168     NaN      o_8  NaN  NaN  NaN  NaN  NaN
# 1    offer viewed       p_1   216     NaN      o_8  NaN  NaN  NaN  NaN  NaN
# 2  offer received       p_1   336     NaN      o_5  NaN  NaN  NaN  NaN  0.0
# 3    offer viewed       p_1   348     NaN      o_5  NaN  NaN  NaN  NaN  0.0
# 4     transaction       p_1   360    0.35      NaN  NaN  NaN  NaN  NaN  0.0
#
#    o_6  o_7  o_8  o_9  o_10
# 0  NaN  NaN  0.0  NaN   NaN
# 1  NaN  NaN  0.0  NaN   NaN
# 2  NaN  NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN   NaN

# %% [markdown]
# ### Measure time for existing flagging formula

# %%
# """create sample dataframe with events of three random customers"""

# transcript_sample = transcript.loc[transcript['person_id'].isin(['p_10126'])]
# transcript_sample = transcript_sample.sort_values(['person_id', 'time']).reset_index(drop=True)



"""define function for activation flagging"""

def flag_for_activation(df):
    """Highlight / flag all transactions that are potentially activating customers. 
    This are the transactions between viewing and completion or if no completion
    between viewing and end of duration.
    
    INPUT:
        - df: dataframe, output from previous flagging function
      
    RETURNS:
        - df: dataframe with updated flags
    """
    
    for col in tqdm(df.columns[-10:]):
        index_start_list = []   
        
        for index in df.index:
            if df.loc[index, 'event'] == 'offer viewed' and df.loc[index, col] == 0:
                index_start = index
                index_start_list.append(index_start)

                for index_start in index_start_list: 
                    for idx in range(index_start, len(df), 1):
                        if df.loc[idx, 'event'] == 'offer received' and df.loc[idx, col] == 0:
                            index_stop = idx 
                            break
                        elif df.loc[idx, 'event'] == 'offer completed' and df.loc[idx, col] == 0:
                            index_stop = idx 
                            break
                        else:
                            index_stop = len(df) 
 
                    if index_stop < index_start:
                        index_stop = len(df)

                print(index, index_start, index_stop)

                for i in range(index_start, index_stop, 1):
                    if df.loc[i, col] == 0:
                        df.loc[i, col] = 1
    
    return df

# %%
# call function, measure runtime

import time
start = time.time()

test_flagged_1 = flag_for_activation(transcript_sample)

print('Duration: {} seconds'.format(time.time() - start))
# Out:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
# 103 103 106
# 26 26 110
# 37 37 66
# 84 84 92
# 93 93 95
# 33 33 47
# 49 49 51
# 77 77 78
# 79 79 104
# 109 109 110
# 3 3 80
# 10 10 15
#  60%|█████████████████████████████████████████████████▊                                 | 6/10 [00:00<00:00, 58.41it/s]
# 6 6 14
# 17 17 71
# 72 72 110
# 1 1 56
# 59 59 70
#  80%|██████████████████████████████████████████████████████████████████▍                | 8/10 [00:00<00:00, 35.53it/s]
# 24 24 54
# 98 98 110
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 36.33it/s]
# Duration: 0.2812492847442627 seconds

# %%
transcript_flagged
# Out:
#                   event person_id  time  amount offer_id  o_1  o_2  o_3  o_4  \
# 0        offer received       p_4     0     NaN      o_3  NaN  NaN  0.0  NaN
# 1          offer viewed       p_4     6     NaN      o_3  NaN  NaN  1.0  NaN
# 2           transaction       p_4   132   19.89      NaN  NaN  NaN  1.0  NaN
# 3       offer completed       p_4   132     NaN      o_3  NaN  NaN  0.0  NaN
# 4           transaction       p_4   144   17.78      NaN  NaN  NaN  0.0  NaN
# 5        offer received       p_4   168     NaN     o_10  NaN  NaN  NaN  NaN
# 6          offer viewed       p_4   216     NaN     o_10  NaN  NaN  NaN  NaN
# 7           transaction       p_4   222   19.67      NaN  NaN  NaN  NaN  NaN
# 8           transaction       p_4   240   29.72      NaN  NaN  NaN  NaN  NaN
# 9           transaction       p_4   378   23.93      NaN  NaN  NaN  NaN  NaN
# 10       offer received       p_4   408     NaN      o_1  0.0  NaN  NaN  NaN
# 11         offer viewed       p_4   408     NaN      o_1  1.0  NaN  NaN  NaN
# 12       offer received       p_4   504     NaN      o_4  NaN  NaN  NaN  0.0
# 13          transaction       p_4   510   21.72      NaN  1.0  NaN  NaN  0.0
# 14      offer completed       p_4   510     NaN      o_1  0.0  NaN  NaN  NaN
# 15      offer completed       p_4   510     NaN      o_4  NaN  NaN  NaN  0.0
# 16          transaction       p_4   534   26.56      NaN  0.0  NaN  NaN  0.0
# 17         offer viewed       p_4   582     NaN      o_4  NaN  NaN  NaN  1.0
# 18       offer received       p_5     0     NaN      o_5  NaN  NaN  NaN  NaN
# 19         offer viewed       p_5     6     NaN      o_5  NaN  NaN  NaN  NaN
# 20          transaction       p_5   234    1.09      NaN  NaN  NaN  NaN  NaN
# 21          transaction       p_5   264    3.50      NaN  NaN  NaN  NaN  NaN
# 22       offer received       p_5   336     NaN      o_9  NaN  NaN  NaN  NaN
# 23         offer viewed       p_5   336     NaN      o_9  NaN  NaN  NaN  NaN
# 24       offer received       p_5   408     NaN     o_10  NaN  NaN  NaN  NaN
# 25       offer received       p_5   504     NaN      o_5  NaN  NaN  NaN  NaN
# 26       offer received       p_5   576     NaN      o_5  NaN  NaN  NaN  NaN
# 27          transaction       p_5   612    0.06      NaN  NaN  NaN  NaN  NaN
# 28         offer viewed       p_5   624     NaN      o_5  NaN  NaN  NaN  NaN
# 29       offer received       p_6     0     NaN      o_8  NaN  NaN  NaN  NaN
# ...                 ...       ...   ...     ...      ...  ...  ...  ...  ...
# 36   offer received     p_101   168     NaN      o_3  NaN  NaN  0.0  NaN  NaN
# 37     offer viewed     p_101   168     NaN      o_3  NaN  NaN  1.0  NaN  NaN
# 38      transaction     p_101   222    4.85      NaN  NaN  NaN  1.0  NaN  NaN
# 39      transaction     p_101   240    4.33      NaN  NaN  NaN  1.0  NaN  NaN
# 40      transaction     p_101   318    2.08      NaN  NaN  NaN  1.0  NaN  NaN
# 41      transaction     p_101   330    1.78      NaN  NaN  NaN  1.0  NaN  NaN
# 42      transaction     p_101   342    5.49      NaN  NaN  NaN  NaN  NaN  NaN
# 43      transaction     p_101   360    3.45      NaN  NaN  NaN  NaN  NaN  NaN
# 44   offer received     p_101   408     NaN      o_9  NaN  NaN  NaN  NaN  NaN
# 45      transaction     p_101   456    3.30      NaN  NaN  NaN  NaN  NaN  NaN
# 46      transaction     p_101   462    1.94      NaN  NaN  NaN  NaN  NaN  NaN
# 47   offer received     p_101   504     NaN      o_4  NaN  NaN  NaN  0.0  NaN
# 48      transaction     p_101   522    1.05      NaN  NaN  NaN  NaN  0.0  NaN
# 49     offer viewed     p_101   534     NaN      o_4  NaN  NaN  NaN  1.0  NaN
# 50      transaction     p_101   594    6.93      NaN  NaN  NaN  NaN  1.0  NaN
# 51  offer completed     p_101   594     NaN      o_4  NaN  NaN  NaN  0.0  NaN
# 52      transaction     p_101   630    1.14      NaN  NaN  NaN  NaN  NaN  NaN
#
#     o_6  o_7  o_8  o_9  o_10
# 35  NaN  NaN  NaN  NaN   NaN
# 36  NaN  NaN  NaN  NaN   NaN
# 37  NaN  NaN  NaN  NaN   NaN
# 38  NaN  NaN  NaN  NaN   NaN
# 39  NaN  NaN  NaN  NaN   NaN
# 40  NaN  NaN  NaN  NaN   NaN
# 41  NaN  NaN  NaN  NaN   NaN
# 42  NaN  NaN  NaN  NaN   NaN
# 43  NaN  NaN  NaN  NaN   NaN
# 44  NaN  NaN  NaN  0.0   NaN
# 45  NaN  NaN  NaN  0.0   NaN
# 46  NaN  NaN  NaN  0.0   NaN
# 47  NaN  NaN  NaN  NaN   NaN
# 48  NaN  NaN  NaN  NaN   NaN
# 49  NaN  NaN  NaN  NaN   NaN
# 50  NaN  NaN  NaN  NaN   NaN
# 51  NaN  NaN  NaN  NaN   NaN
# 52  NaN  NaN  NaN  NaN   NaN

# %% [markdown]
# ### Bugfix - include completed

# %%
def flag_for_completed(df):
    """
    INPUT:
        - df: dataframe, output from previous flagging function
      
    RETURNS:
        - df: dataframe with updated flags
    """
    
    for col in tqdm(df.columns[-10:]):
        index_start_list = []   
        
        for index in df.index:
            if df.loc[index, 'event'] == 'offer viewed' and df.loc[index, col] == 1:
                index_start = index
                index_start_list.append(index_start)

                for index_start in index_start_list: 
                    for idx in range(index_start, df.index[-1], 1):
                        if df.loc[idx, 'event'] == 'offer received' and df.loc[idx, col] == 0:
                            break
                        elif df.loc[idx, 'event'] == 'offer completed' and df.loc[idx, col] == 0:
                                df.loc[idx, col] = 1
                                break
            
    return df

# %%
transcript_flagged.loc[285041 : , :]
# Out:
#  60%|█████████████████████████████████████████████████▊                                 | 6/10 [06:44<04:36, 69.19s/it]
#
#
#
#
#
#
#
#
#
#
#  70%|██████████████████████████████████████████████████████████                         | 7/10 [08:18<03:49, 76.47s/it]
#
#
#
#
#
#
#
#
#
#
#  80%|██████████████████████████████████████████████████████████████████▍                | 8/10 [08:48<02:05, 62.54s/it]
#
#
#
#
#
#
#
#
#
#
#  90%|██████████████████████████████████████████████████████████████████████████▋        | 9/10 [09:13<00:51, 51.37s/it]
#
#
#
#
#
#
#
#
#
#
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [10:18<00:00, 55.52s/it]

# %%
print(len(flag_13))
print(flag_13.head(15))
# Out:
# 24997
#                   event person_id  time  amount offer_id  o_1  o_2  o_3  o_4  \
# 235047   offer received   p_16794     0     NaN     o_10  NaN  NaN  NaN  NaN
# 235048      transaction   p_16794     0   10.65      NaN  NaN  NaN  NaN  NaN
# 235049     offer viewed   p_16794    24     NaN     o_10  NaN  NaN  NaN  NaN
# 235050   offer received   p_16794   168     NaN      o_8  NaN  NaN  NaN  NaN
# 235051     offer viewed   p_16794   180     NaN      o_8  NaN  NaN  NaN  NaN
# 235052      transaction   p_16794   246   22.50      NaN  NaN  NaN  NaN  NaN
# 235053  offer completed   p_16794   246     NaN      o_8  NaN  NaN  NaN  NaN
# 235054   offer received   p_16794   336     NaN      o_3  NaN  NaN  0.0  NaN
# 235055     offer viewed   p_16794   360     NaN      o_3  NaN  NaN  1.0  NaN
# 235056   offer received   p_16794   408     NaN      o_7  NaN  NaN  NaN  NaN
# 235057     offer viewed   p_16794   438     NaN      o_7  NaN  NaN  NaN  NaN
# 235058      transaction   p_16794   606   14.68      NaN  NaN  NaN  NaN  NaN
# 235059  offer completed   p_16794   606     NaN      o_7  NaN  NaN  NaN  NaN
# 235060      transaction   p_16794   684   12.15      NaN  NaN  NaN  NaN  NaN
# 235061   offer received   p_16795     0     NaN      o_4  NaN  NaN  NaN  0.0
#
#         o_5  o_6  o_7  o_8  o_9  o_10
# 235047  NaN  NaN  NaN  NaN  NaN   0.0
# 235048  NaN  NaN  NaN  NaN  NaN   0.0
# 235049  NaN  NaN  NaN  NaN  NaN   1.0
# 235050  NaN  NaN  NaN  0.0  NaN   NaN
# 235051  NaN  NaN  NaN  1.0  NaN   NaN
# 235052  NaN  NaN  NaN  1.0  NaN   NaN
# 235053  NaN  NaN  NaN  1.0  NaN   NaN
# 235054  NaN  NaN  NaN  NaN  NaN   NaN
# 235055  NaN  NaN  NaN  NaN  NaN   NaN
# 235056  NaN  NaN  0.0  NaN  NaN   NaN
# 235057  NaN  NaN  1.0  NaN  NaN   NaN
# 235058  NaN  NaN  1.0  NaN  NaN   NaN
# 235059  NaN  NaN  1.0  NaN  NaN   NaN
# 235060  NaN  NaN  NaN  NaN  NaN   NaN
# 235061  NaN  NaN  NaN  NaN  NaN   NaN

# %%
flagged_new = pd.concat([flag_1, flag_2, flag_3, flag_4, flag_5, flag_6, flag_7, flag_8, flag_9, flag_10, flag_11, flag_12, flag_13, flag_14, flag_15])

# %%
assert list(flagged_new['person_id']) == list(transcript_flagged['person_id'])

# %%
transcript_flagged_new = Path.cwd() / "data" / "interim" / "transcript_flagged_v2.csv"
flagged_new.to_csv(transcript_flagged_new, index=False)

# %%
to_be_flagged.index[-1]
# Out:
# 30006

# %%
# call function, measure runtime

import time
start = time.time()

flag_2 = flag_for_completed(to_be_flagged)

print('Duration: {} seconds'.format(time.time() - start))
# Out:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#  10%|████████▎                                                                          | 1/10 [00:00<00:02,  4.43it/s]
#
#
#
#
#
#
#
#
#  20%|████████████████▌                                                                  | 2/10 [00:00<00:01,  4.58it/s]
#
#
#
#
#
#
#
#
#  30%|████████████████████████▉                                                          | 3/10 [00:00<00:01,  4.99it/s]
#
#
#
#
#
#
#
#
#  40%|█████████████████████████████████▏                                                 | 4/10 [00:00<00:01,  5.06it/s]
#
#
#
#
#
#
#
#
#  50%|█████████████████████████████████████████▌                                         | 5/10 [00:00<00:00,  5.54it/s]
#
#
#
#
#
#
#
#
#  60%|█████████████████████████████████████████████████▊                                 | 6/10 [00:01<00:00,  5.58it/s]
#
#
#
#
#
#
#
#
#  70%|██████████████████████████████████████████████████████████                         | 7/10 [00:01<00:00,  5.24it/s]
#
#
#
#
#
#
#
#
#  80%|██████████████████████████████████████████████████████████████████▍                | 8/10 [00:01<00:00,  4.99it/s]
#
#
#
#
#
#
#
#
#  90%|██████████████████████████████████████████████████████████████████████████▋        | 9/10 [00:01<00:00,  5.18it/s]
#
#
#
#
#
#
#
#
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:01<00:00,  5.06it/s]
# Duration: 1.9182631969451904 seconds

# %%
test_flagged_2.loc[test_flagged_2['person_id'] == 'p_4']
# Out:
#                event person_id  time  amount offer_id  o_1  o_2  o_3  o_4  \
# 92    offer received       p_4     0     NaN      o_3  NaN  NaN  0.0  NaN
# 93      offer viewed       p_4     6     NaN      o_3  NaN  NaN  1.0  NaN
# 94       transaction       p_4   132   19.89      NaN  NaN  NaN  1.0  NaN
# 95   offer completed       p_4   132     NaN      o_3  NaN  NaN  1.0  NaN
# 96       transaction       p_4   144   17.78      NaN  NaN  NaN  0.0  NaN
# 97    offer received       p_4   168     NaN     o_10  NaN  NaN  NaN  NaN
# 98      offer viewed       p_4   216     NaN     o_10  NaN  NaN  NaN  NaN
# 99       transaction       p_4   222   19.67      NaN  NaN  NaN  NaN  NaN
# 100      transaction       p_4   240   29.72      NaN  NaN  NaN  NaN  NaN
# 101      transaction       p_4   378   23.93      NaN  NaN  NaN  NaN  NaN
# 102   offer received       p_4   408     NaN      o_1  0.0  NaN  NaN  NaN
# 103     offer viewed       p_4   408     NaN      o_1  1.0  NaN  NaN  NaN
# 104   offer received       p_4   504     NaN      o_4  NaN  NaN  NaN  0.0
# 105      transaction       p_4   510   21.72      NaN  1.0  NaN  NaN  0.0
# 106  offer completed       p_4   510     NaN      o_1  1.0  NaN  NaN  NaN
# 107  offer completed       p_4   510     NaN      o_4  NaN  NaN  NaN  0.0
# 108      transaction       p_4   534   26.56      NaN  0.0  NaN  NaN  0.0
# 109     offer viewed       p_4   582     NaN      o_4  NaN  NaN  NaN  1.0
#
#      o_5  o_6  o_7  o_8  o_9  o_10
# 92   NaN  NaN  NaN  NaN  NaN   NaN
# 93   NaN  NaN  NaN  NaN  NaN   NaN
# 94   NaN  NaN  NaN  NaN  NaN   NaN
# 95   NaN  NaN  NaN  NaN  NaN   NaN
# 96   NaN  NaN  NaN  NaN  NaN   NaN
# 97   NaN  NaN  NaN  NaN  NaN   0.0
# 98   NaN  NaN  NaN  NaN  NaN   1.0
# 99   NaN  NaN  NaN  NaN  NaN   1.0
# 100  NaN  NaN  NaN  NaN  NaN   NaN
# 101  NaN  NaN  NaN  NaN  NaN   NaN
# 102  NaN  NaN  NaN  NaN  NaN   NaN
# 103  NaN  NaN  NaN  NaN  NaN   NaN
# 104  NaN  NaN  NaN  NaN  NaN   NaN
# 105  NaN  NaN  NaN  NaN  NaN   NaN
# 106  NaN  NaN  NaN  NaN  NaN   NaN
# 107  NaN  NaN  NaN  NaN  NaN   NaN
# 108  NaN  NaN  NaN  NaN  NaN   NaN
# 109  NaN  NaN  NaN  NaN  NaN   NaN

# %%
"""define function for timespan flagging"""

# create a look-up dict containing the duration for the different offers
duration_dict = dict(zip(portfolio.index, portfolio['duration_hours']))

def flag_completed(df):
    """Create dummy columns for all promotions and set flag of value 0 if an event 
    belongs to a promotion or a transaction falls into the duration timespan.
    
    ARGUMENTS:
        - df: dataframe, containing the pre-cleaned transactions
        - columns_list: list, containing the columns for the extended df
        - duration_dict: dict, containing offer ids as key, durations as values
      
    RETURNS:
        - df_extended: dataframe with flagged dummy columns added
    """
    
    # initialize empty df with dummy columns
    df_extended = pd.DataFrame(columns=columns_list)

    for person in tqdm(df['person_id'].unique()):
        df_slice = df.loc[df['person_id'] == person]
    
        for index in df_slice.index:
            if df_slice.loc[index, 'event'] == 'offer received':
                o_id = df_slice.loc[index, 'offer_id']
                o_start = df_slice.loc[index, 'time']
                o_duration = duration_dict[o_id]
                o_end = o_start + o_duration - 1
#                 print(person, o_id, o_start, o_duration, o_end)

                df_slice[o_id] = np.where((df_slice['time'] >= o_start) & (df_slice['time'] <= o_end) \
                                         & ((df_slice['amount'] >= 0) | (df_slice['offer_id'] == o_id)), \
                                                     0, df_slice[o_id])
#         display(df_slice)
        df_extended = pd.concat([df_extended, df_slice], join='outer')
    
    return df_extended

# %%
BREAK here
# Out:
#   File "<ipython-input-7-dc25f03f46ca>", line 1
#     BREAK here
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Backup: old experimentation / function creation

# %%
# extend transcript with an empty column for each promotion
columns_list = list(transcript.columns)+ list(portfolio['offer_id'].values)
transcript = transcript.reindex(columns=columns_list)  # reindex creates df with all NaNs for new cols

# %%
# check result
display(transcript.head(2))

# %%
# make sample dataframe
transcript_sample = transcript.loc[transcript['person_id'].isin(['p_200', 'p_10126', 'p_1'])]
transcript_sample = transcript_sample.sort_values(['person_id', 'time'])
display(transcript_sample)

# %%
# flag for duration

duration_dict = dict(zip(portfolio['offer_id'], portfolio['duration_hours']))

transcript_extended = pd.DataFrame(columns=transcript.columns)

for person in transcript_sample['person_id'].unique():
    t_slice = transcript_sample.loc[transcript_sample['person_id'] == person]
    
    for index, row in t_slice.iterrows():
        if t_slice.loc[index, 'event'] == 'offer received':  
            o_id = t_slice.loc[index, 'offer_id']
            o_start = t_slice.loc[index, 'time']
            o_duration = duration_dict[o_id]
            o_end = o_start + o_duration - 1
            print(person, o_id, o_start, o_duration, o_end)
            
            t_slice[o_id] = np.where((t_slice['time'] >= o_start) & (t_slice['time'] <= o_end) \
                                     & ((t_slice['amount'] >= 0) | (t_slice['offer_id'] == o_id)), \
                                                 1, t_slice[o_id])
    display(t_slice)
    
    transcript_extended = pd.concat([transcript_extended, t_slice], join='outer')

# %%
duration_dict

# %%
transcript_extended

# %%
transcript_extended.reset_index(inplace=True, drop=True)

# %%
transcript_extended

# %%
transcript_extended[['event', 'person_id', 'offer_id', 'o_7']]

# %%
"""create sample dataframe with events of three random customers"""

transcript_sample = transcript.loc[transcript['person_id'].isin(['p_1', 'p_2', 'p_3'])]  # ['p_200', 'p_10126', 'p_1']
transcript_sample = transcript_sample.sort_values(['person_id', 'time']).reset_index(drop=True)
display(transcript_sample)
# Out:
#               event person_id  time  amount offer_id  o_1  o_2  o_3  o_4  o_5  \
# 0    offer received       p_1   168     NaN      o_8  NaN  NaN  NaN  NaN  NaN
# 1      offer viewed       p_1   216     NaN      o_8  NaN  NaN  NaN  NaN  NaN
# 2    offer received       p_1   336     NaN      o_5  NaN  NaN  NaN  NaN  0.0
# 3      offer viewed       p_1   348     NaN      o_5  NaN  NaN  NaN  NaN  0.0
# 4       transaction       p_1   360    0.35      NaN  NaN  NaN  NaN  NaN  0.0
# 5    offer received       p_1   408     NaN      o_7  NaN  NaN  NaN  NaN  NaN
# 6      offer viewed       p_1   408     NaN      o_7  NaN  NaN  NaN  NaN  NaN
# 7       transaction       p_1   414    0.74      NaN  NaN  NaN  NaN  NaN  0.0
# 8       transaction       p_1   444    1.89      NaN  NaN  NaN  NaN  NaN  0.0
# 9    offer received       p_1   504     NaN      o_6  NaN  NaN  NaN  NaN  NaN
# 10     offer viewed       p_1   504     NaN      o_6  NaN  NaN  NaN  NaN  NaN
# 11      transaction       p_1   510    5.04      NaN  NaN  NaN  NaN  NaN  0.0
# 12      transaction       p_1   534    0.38      NaN  NaN  NaN  NaN  NaN  0.0
# 13      transaction       p_1   552    2.12      NaN  NaN  NaN  NaN  NaN  0.0
# 14  offer completed       p_1   552     NaN      o_7  NaN  NaN  NaN  NaN  NaN
# 15  offer completed       p_1   552     NaN      o_6  NaN  NaN  NaN  NaN  NaN
# 16   offer received       p_1   576     NaN      o_7  NaN  NaN  NaN  NaN  NaN
# 17     offer viewed       p_1   582     NaN      o_7  NaN  NaN  NaN  NaN  NaN
# 18      transaction       p_1   606    4.61      NaN  NaN  NaN  NaN  NaN  NaN
# 19      transaction       p_1   630    0.06      NaN  NaN  NaN  NaN  NaN  NaN
# 20      transaction       p_1   696    5.21      NaN  NaN  NaN  NaN  NaN  NaN
# 21      transaction       p_2    18   21.51      NaN  NaN  NaN  NaN  NaN  NaN
# 22      transaction       p_2   144   32.28      NaN  NaN  NaN  NaN  NaN  NaN
# 23   offer received       p_2   408     NaN      o_3  NaN  NaN  0.0  NaN  NaN
# 24   offer received       p_2   504     NaN      o_9  NaN  NaN  NaN  NaN  NaN
# 25      transaction       p_2   528   23.22      NaN  NaN  NaN  0.0  NaN  NaN
# 26  offer completed       p_2   528     NaN      o_3  NaN  NaN  0.0  NaN  NaN
# 27      transaction       p_3   132    1.34      NaN  NaN  NaN  NaN  NaN  NaN
# 28   offer received       p_3   168     NaN      o_3  NaN  NaN  0.0  NaN  NaN
# 29     offer viewed       p_3   168     NaN      o_3  NaN  NaN  0.0  NaN  NaN
# 30      transaction       p_3   348    1.64      NaN  NaN  NaN  NaN  NaN  NaN
# 31      transaction       p_3   450    3.47      NaN  NaN  NaN  NaN  NaN  NaN
# 32      transaction       p_3   474    1.62      NaN  NaN  NaN  NaN  NaN  NaN
# 33   offer received       p_3   576     NaN     o_10  NaN  NaN  NaN  NaN  NaN
# 34      transaction       p_3   636    2.14      NaN  NaN  NaN  NaN  NaN  NaN
# 35     offer viewed       p_3   666     NaN     o_10  NaN  NaN  NaN  NaN  NaN
# 36      transaction       p_3   696    4.09      NaN  NaN  NaN  NaN  NaN  NaN
#
#     o_6  o_7  o_8  o_9  o_10
# 0   NaN  NaN  0.0  NaN   NaN
# 1   NaN  NaN  0.0  NaN   NaN
# 2   NaN  NaN  NaN  NaN   NaN
# 3   NaN  NaN  NaN  NaN   NaN
# 4   NaN  NaN  NaN  NaN   NaN
# 5   NaN  0.0  NaN  NaN   NaN
# 6   NaN  0.0  NaN  NaN   NaN
# 7   NaN  0.0  NaN  NaN   NaN
# 8   NaN  0.0  NaN  NaN   NaN
# 9   0.0  NaN  NaN  NaN   NaN
# 10  0.0  NaN  NaN  NaN   NaN
# 11  0.0  0.0  NaN  NaN   NaN
# 12  0.0  0.0  NaN  NaN   NaN
# 13  0.0  0.0  NaN  NaN   NaN
# 14  NaN  0.0  NaN  NaN   NaN
# 15  0.0  NaN  NaN  NaN   NaN
# 16  NaN  0.0  NaN  NaN   NaN
# 17  NaN  0.0  NaN  NaN   NaN
# 18  0.0  0.0  NaN  NaN   NaN
# 19  0.0  0.0  NaN  NaN   NaN
# 20  NaN  0.0  NaN  NaN   NaN
# 21  NaN  NaN  NaN  NaN   NaN
# 22  NaN  NaN  NaN  NaN   NaN
# 23  NaN  NaN  NaN  NaN   NaN
# 24  NaN  NaN  NaN  0.0   NaN
# 25  NaN  NaN  NaN  0.0   NaN
# 26  NaN  NaN  NaN  NaN   NaN
# 27  NaN  NaN  NaN  NaN   NaN
# 28  NaN  NaN  NaN  NaN   NaN
# 29  NaN  NaN  NaN  NaN   NaN
# 30  NaN  NaN  NaN  NaN   NaN
# 31  NaN  NaN  NaN  NaN   NaN
# 32  NaN  NaN  NaN  NaN   NaN
# 33  NaN  NaN  NaN  NaN   0.0
# 34  NaN  NaN  NaN  NaN   0.0
# 35  NaN  NaN  NaN  NaN   NaN
# 36  NaN  NaN  NaN  NaN   NaN

# %%
"""create sample dataframe with events of three random customers"""

transcript_sample = transcript.loc[transcript['person_id'].isin(['p_1', 'p_2', 'p_3', 'p_200', 'p_10126', 'p_10', 'p_101', 'p_4'])]
transcript_sample = transcript_sample.sort_values(['person_id', 'time']).reset_index(drop=True)

# flag for activation

def function_v(transcript_extended):
    
    for col in transcript_extended.columns[-10:]:
        index_start_list = []   
        for index, row in transcript_extended.iterrows():

            if transcript_extended.loc[index, 'event'] == 'offer viewed' and transcript_extended.loc[index, col] == 0:
                index_start = index
                index_start_list.append(index_start)

                for index_start in index_start_list:    
                    for idx, roww in transcript_extended.loc[index_start: , :].iterrows():
                        if transcript_extended.loc[idx, 'event'] == 'offer received' and transcript_extended.loc[idx, col] == 0:
                            index_stop = idx-1
                            break
                        elif transcript_extended.loc[idx, 'event'] == 'offer completed' and transcript_extended.loc[idx, col] == 0:
                            index_stop = idx
                            break
                        else:
                            index_stop = len(transcript_extended) - 1 
                            
                    if index_stop < index_start:
                        index_stop = len(transcript_extended) -1

                print(index, index_start, index_stop)

#                 transcript_extended.loc[index_start : index_stop, col].apply(lambda x: 'v' if x == 1 else np.nan)
#                 transcript_extended.loc[index_start : index_stop, col].replace(1, 'v', inplace=True)
    
                for i, rowwww in transcript_extended.loc[index_start: index_stop].iterrows():
                    if transcript_extended.loc[i, col] == 0:
                        transcript_extended.loc[i, col] = 1

    return transcript_extended

# %%
import time
start = time.time()

transcript_test = function_v(transcript_extended = transcript_sample)

print('Duration: {} seconds'.format(time.time() - start))
# Out:
# 103 103 106
# 26 26 109
# 37 37 65
# 84 84 91
# 93 93 95
# 33 33 46
# 49 49 51
# 77 77 77
# 79 79 103
# 109 109 109
# 3 3 79
# 10 10 15
# 6 6 14
# 17 17 70
# 72 72 109
# 1 1 55
# 59 59 69
# 24 24 53
# 98 98 109
# Duration: 0.6101329326629639 seconds

# %%
transcript_test
# Out:
#               event person_id  time  amount offer_id  o_1  o_2  o_3  o_4  o_5  \
# 0    offer received       p_1   168     NaN      o_8  NaN  NaN  NaN  NaN  NaN
# 1      offer viewed       p_1   216     NaN      o_8  NaN  NaN  NaN  NaN  NaN
# 2    offer received       p_1   336     NaN      o_5  NaN  NaN  NaN  NaN    0
# 3      offer viewed       p_1   348     NaN      o_5  NaN  NaN  NaN  NaN    v
# 4       transaction       p_1   360    0.35      NaN  NaN  NaN  NaN  NaN    v
# 5    offer received       p_1   408     NaN      o_7  NaN  NaN  NaN  NaN  NaN
# 6      offer viewed       p_1   408     NaN      o_7  NaN  NaN  NaN  NaN  NaN
# 7       transaction       p_1   414    0.74      NaN  NaN  NaN  NaN  NaN    v
# 8       transaction       p_1   444    1.89      NaN  NaN  NaN  NaN  NaN    v
# 9    offer received       p_1   504     NaN      o_6  NaN  NaN  NaN  NaN  NaN
# 10     offer viewed       p_1   504     NaN      o_6  NaN  NaN  NaN  NaN  NaN
# 11      transaction       p_1   510    5.04      NaN  NaN  NaN  NaN  NaN    v
# 12      transaction       p_1   534    0.38      NaN  NaN  NaN  NaN  NaN    v
# 13      transaction       p_1   552    2.12      NaN  NaN  NaN  NaN  NaN    v
# 14  offer completed       p_1   552     NaN      o_7  NaN  NaN  NaN  NaN  NaN
# 15  offer completed       p_1   552     NaN      o_6  NaN  NaN  NaN  NaN  NaN
# 16   offer received       p_1   576     NaN      o_7  NaN  NaN  NaN  NaN  NaN
# 17     offer viewed       p_1   582     NaN      o_7  NaN  NaN  NaN  NaN  NaN
# 18      transaction       p_1   606    4.61      NaN  NaN  NaN  NaN  NaN  NaN
# 19      transaction       p_1   630    0.06      NaN  NaN  NaN  NaN  NaN  NaN
# 20      transaction       p_1   696    5.21      NaN  NaN  NaN  NaN  NaN  NaN
