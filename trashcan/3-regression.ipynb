# %% [markdown]
# # Regression Modelling
#
# Preprocess Data & Run Regression Algorithms to determine the importance / success of different promotions for different customer segments.
#
#
# ### Data Sources
#
# Cleaned datafile, as prepared in notebook 1:
# - profile_long_clean.csv - demographic data, offer data and transaction data for each customer
#
# ### Changes
#
# - 2019-01-10: Started notebook

# %%
# load libraries

import numpy as np
import pandas as pd
from tqdm import tqdm

# my own custom functions
import EDA_functions as EDA
import cleaning_functions as cleaning
from linRegModel_class import LinRegModel 

from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.utils import resample  # for error calculation of feature weights

# visualization
import matplotlib.pyplot as plt
import seaborn as sns #, sns.set_style('whitegrid')
color = 'rebeccapurple'
# %matplotlib inline

# display settings
from IPython.display import display
pd.options.display.max_columns = None

from pathlib import Path  # to make file path references relative to notebook directory

# %%
# import data

profile_file = Path.cwd() / "data" / "processed" / "profile_long_clean.csv"
profile = pd.read_csv(profile_file, index_col = 0)

# %% [markdown]
# ## Check profile (long) data

# %%
display(profile.head())
display(profile.info())
# Out:
#             age gender   income  member_days  completed_viewed  total_trans  \
# person_id
# p_1         NaN    NaN      NaN         -529               2.0          9.0
# p_10        NaN    NaN      NaN         -611               0.0          6.0
# p_100      68.0      F  84000.0         -725               0.0          2.0
# p_1000     67.0      M  44000.0         -225               0.0          5.0
# p_10000     NaN    NaN      NaN         -446               0.0          6.0
#
#            total_amount  total_mean_amount  np_trans  np_amount  \
# person_id
# p_1               20.40           2.266667         0       0.00
# p_10              15.62           2.603333         3       7.69
# p_100             34.04          17.020000         2      34.04
# p_1000            19.78           3.956000         2      13.37
# p_10000            7.28           1.213333         1       1.83
#
#            np_mean_amount  prop_np_trans  prop_np_amount  \
# person_id
# p_1              0.000000       0.000000        0.000000
# p_10             2.563333       0.500000        0.492318
# p_100           17.020000       1.000000        1.000000
# p_1000           6.685000       0.400000        0.675935
# p_10000          1.830000       0.166667        0.251374
#
#            ('o_1', 'offer received')  ('o_1', 'offer viewed')  \
# person_id
# p_1                              0.0                      0.0
# p_10                             0.0                      0.0
# p_100                            1.0                      0.0
# p_1000                           0.0                      0.0
# p_10000                          0.0                      0.0
#
#            ('o_1', 'offer completed')  ('o_1', 'transactions')  \
# person_id
# p_1                               0.0                      0.0
# p_10                              0.0                      0.0
# p_100                             0.0                      0.0
# p_1000                            0.0                      0.0
# p_10000                           0.0                      0.0
#
#            ('o_2', 'offer received')  ('o_2', 'offer viewed')  \
# person_id
# p_1                              0.0                      0.0
# p_10                             1.0                      1.0
# p_100                            0.0                      0.0
# p_1000                           1.0                      1.0
# p_10000                          0.0                      0.0
#
#            ('o_2', 'offer completed')  ('o_2', 'transactions')  \
# person_id
# p_1                               0.0                      0.0
# p_10                              0.0                      2.0
# p_100                             0.0                      0.0
# p_1000                            0.0                      1.0
# p_10000                           0.0                      0.0
#
#            ('o_3', 'offer received')  ('o_3', 'offer viewed')  \
# person_id
# p_1                              0.0                      0.0
# p_10                             1.0                      0.0
# p_100                            0.0                      0.0
# p_1000                           0.0                      0.0
# p_10000                          1.0                      1.0
#
#            ('o_3', 'offer completed')  ('o_3', 'transactions')  \
# person_id
# p_1                               0.0                      0.0
# p_10                              1.0                      2.0
# p_100                             0.0                      0.0
# p_1000                            0.0                      0.0
# p_10000                           0.0                      3.0
#
#            ('o_4', 'offer received')  ('o_4', 'offer viewed')  \
# person_id
# p_1                              0.0                      0.0
# p_10                             1.0                      1.0
# p_100                            0.0                      0.0
# p_1000                           2.0                      2.0
# p_10000                          1.0                      1.0
#
#            ('o_4', 'offer completed')  ('o_4', 'transactions')  \
# person_id
# p_1                               0.0                      0.0
# p_10                              0.0                      1.0
# p_100                             0.0                      0.0
# p_1000                            0.0                      2.0
# p_10000                           0.0                      2.0
#
#            ('o_5', 'offer received')  ('o_5', 'offer viewed')  \
# person_id
# p_1                              1.0                      1.0
# p_10                             0.0                      0.0
# p_100                            2.0                      0.0
# p_1000                           0.0                      0.0
# p_10000                          0.0                      0.0
#
#            ('o_5', 'offer completed')  ('o_5', 'transactions')  \
# person_id
# p_1                               0.0                      6.0
# p_10                              0.0                      0.0
# p_100                             0.0                      1.0
# p_1000                            0.0                      0.0
# p_10000                           0.0                      0.0
#
#            ('o_6', 'offer received')  ('o_6', 'offer viewed')  \
# person_id
# p_1                              1.0                      1.0
# p_10                             0.0                      0.0
# p_100                            0.0                      0.0
# p_1000                           0.0                      0.0
# p_10000                          1.0                      1.0
#
#            ('o_6', 'offer completed')  ('o_6', 'transactions')  \
# person_id
# p_1                               1.0                      5.0
# p_10                              0.0                      0.0
# p_100                             0.0                      0.0
# p_1000                            0.0                      0.0
# p_10000                           0.0                      3.0
#
#            ('o_7', 'offer received')  ('o_7', 'offer viewed')  \
# person_id
# p_1                              2.0                      2.0
# p_10                             0.0                      0.0
# p_100                            0.0                      0.0
# p_1000                           0.0                      0.0
# p_10000                          0.0                      0.0
#
#            ('o_7', 'offer completed')  ('o_7', 'transactions')  \
# person_id
# p_1                               1.0                      8.0
# p_10                              0.0                      0.0
# p_100                             0.0                      0.0
# p_1000                            0.0                      0.0
# p_10000                           0.0                      0.0
#
#            ('o_8', 'offer received')  ('o_8', 'offer viewed')  \
# person_id
# p_1                              1.0                      1.0
# p_10                             0.0                      0.0
# p_100                            1.0                      0.0
# p_1000                           0.0                      0.0
# p_10000                          0.0                      0.0
#
#            ('o_8', 'offer completed')  ('o_8', 'transactions')  \
# person_id
# p_1                               0.0                      0.0
# p_10                              0.0                      0.0
# p_100                             1.0                      1.0
# p_1000                            0.0                      0.0
# p_10000                           0.0                      0.0
#
#            ('o_9', 'offer received')  ('o_9', 'offer viewed')  \
# person_id
# p_1                              0.0                      0.0
# p_10                             0.0                      0.0
# p_100                            1.0                      0.0
# p_1000                           0.0                      0.0
# p_10000                          0.0                      0.0
#
#            ('o_9', 'offer completed')  ('o_9', 'transactions')  \
# person_id
# p_1                               0.0                      0.0
# p_10                              0.0                      0.0
# p_100                             0.0                      0.0
# p_1000                            0.0                      0.0
# p_10000                           0.0                      0.0
#
#            ('o_10', 'offer received')  ('o_10', 'offer viewed')  \
# person_id
# p_1                               0.0                       0.0
# p_10                              1.0                       1.0
# p_100                             0.0                       0.0
# p_1000                            1.0                       1.0
# p_10000                           0.0                       0.0
#
#            ('o_10', 'offer completed')  ('o_10', 'transactions')
# person_id
# p_1                                0.0                       0.0
# p_10                               0.0                       0.0
# p_100                              0.0                       0.0
# p_1000                             0.0                       1.0
# p_10000                            0.0                       0.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 17000 entries, p_1 to p_9999
# Data columns (total 53 columns):
# age                            14825 non-null float64
# gender                         14825 non-null object
# income                         14825 non-null float64
# member_days                    17000 non-null int64
# completed_viewed               17000 non-null float64
# total_trans                    17000 non-null float64
# total_amount                   17000 non-null float64
# total_mean_amount              17000 non-null float64
# np_trans                       17000 non-null int64
# np_amount                      17000 non-null float64
# np_mean_amount                 17000 non-null float64
# prop_np_trans                  17000 non-null float64
# prop_np_amount                 17000 non-null float64
# ('o_1', 'offer received')      17000 non-null float64
# ('o_1', 'offer viewed')        17000 non-null float64
# ('o_1', 'offer completed')     17000 non-null float64
# ('o_1', 'transactions')        17000 non-null float64
# ('o_2', 'offer received')      17000 non-null float64
# ('o_2', 'offer viewed')        17000 non-null float64
# ('o_2', 'offer completed')     17000 non-null float64
# ('o_2', 'transactions')        17000 non-null float64
# ('o_3', 'offer received')      17000 non-null float64
# ('o_3', 'offer viewed')        17000 non-null float64
# ('o_3', 'offer completed')     17000 non-null float64
# ('o_3', 'transactions')        17000 non-null float64
# ('o_4', 'offer received')      17000 non-null float64
# ('o_4', 'offer viewed')        17000 non-null float64
# ('o_4', 'offer completed')     17000 non-null float64
# ('o_4', 'transactions')        17000 non-null float64
# ('o_5', 'offer received')      17000 non-null float64
# ('o_5', 'offer viewed')        17000 non-null float64
# ('o_5', 'offer completed')     17000 non-null float64
# ('o_5', 'transactions')        17000 non-null float64
# ('o_6', 'offer received')      17000 non-null float64
# ('o_6', 'offer viewed')        17000 non-null float64
# ('o_6', 'offer completed')     17000 non-null float64
# ('o_6', 'transactions')        17000 non-null float64
# ('o_7', 'offer received')      17000 non-null float64
# ('o_7', 'offer viewed')        17000 non-null float64
# ('o_7', 'offer completed')     17000 non-null float64
# ('o_7', 'transactions')        17000 non-null float64
# ('o_8', 'offer received')      17000 non-null float64
# ('o_8', 'offer viewed')        17000 non-null float64
# ('o_8', 'offer completed')     17000 non-null float64
# ('o_8', 'transactions')        17000 non-null float64
# ('o_9', 'offer received')      17000 non-null float64
# ('o_9', 'offer viewed')        17000 non-null float64
# ('o_9', 'offer completed')     17000 non-null float64
# ('o_9', 'transactions')        17000 non-null float64
# ('o_10', 'offer received')     17000 non-null float64
# ('o_10', 'offer viewed')       17000 non-null float64
# ('o_10', 'offer completed')    17000 non-null float64
# ('o_10', 'transactions')       17000 non-null float64
# dtypes: float64(50), int64(2), object(1)
# memory usage: 7.0+ MB
# None

# %%
# """eliminiate missing values"""

# profile = cleaning.handle_NaN(profile, cols_to_impute_num=['age', 'income'])
# profile['gender'] = profile['gender'].fillna('u')

# %%
# check results
# profile.head()

# %% [markdown]
# ## Run quick and dirty linear regression

# %%
"initialize and run base model"

# define a scikit-learn model object you want to work with
model = LinearRegression(normalize=True)
# create an instance of the LinRegModel class by passing the dataframe, the target variable and the model object
linReg_simple = LinRegModel(profile, 'total_amount', model)
# go
linReg_simple.go_quickDirty()

# %%
# check performance
linReg_simple
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
#
# RMSE on test data 38.62, r2-score 0.91.

# %%
"""plot learning curves using 5-fold cross validation"""
linReg_simple.plot_learning_curves()
# Out:
# [learning_curve] Training set sizes: [  95  591 1087 1583 2079 2575 3071 3567 4063 4559 5055 5551 6047 6543
#  7039 7535 8031 8527 9023 9520]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    3.9s finished

# %% [markdown]
# ### Check results for Ridge, Lasso, ElasticNet

# %%
# define RidgeCV without normalization but higher alphas)
model = RidgeCV(alphas=[30, 50, 70], cv=3, fit_intercept=True)
# instantiate
ridgeCV_simple = LinRegModel(profile, 'total_amount', model)
# perform linear regression modelling
ridgeCV_simple.go_quickDirty()
# output scores
ridgeCV_simple
# Out:
# RidgeCV(alphas=array([30, 50, 70]), cv=3, fit_intercept=True, gcv_mode=None,
#     normalize=False, scoring=None, store_cv_values=False)
#
# RMSE on test data 38.71, r2-score 0.91.

# %%
model.alpha_
# Out:
# 30

# %%
# plot feature weights
# ridgeCV_simple.print_coef_weights(n_bootstrap=10)

# %%
# define lassoCV without normalization (but higher alphas)
model = LassoCV(alphas=[0.01, 0.1, 1],cv=3, fit_intercept=True)
# instantiate
lassoCV_simple = LinRegModel(profile, 'total_amount', model)
# perform linear regression modelling
lassoCV_simple.go_quickDirty()
# output scores
lassoCV_simple
# Out:
# LassoCV(alphas=[0.01, 0.1, 1], copy_X=True, cv=3, eps=0.001,
#     fit_intercept=True, max_iter=1000, n_alphas=100, n_jobs=None,
#     normalize=False, positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)
#
# RMSE on test data 38.63, r2-score 0.91.

# %%
model.alpha_
# Out:
# 0.01

# %%
# plot feature weights
lassoCV_simple.print_coef_weights(n_bootstrap=10)
# Out:
#                              effect  error
# prop_np_amount                -63.4    0.0
# prop_np_trans                  38.7    0.0
# ('o_2', 'offer completed')     15.7    0.0
# ('o_1', 'offer completed')     14.0    1.0
# ('o_4', 'offer completed')     10.9    0.0
# ('o_7', 'offer completed')      8.7    0.0
# ('o_1', 'offer received')      -7.4    1.0
# ('o_5', 'offer viewed')         6.9    0.0
# ('o_6', 'offer completed')      6.5    0.0
# ('o_1', 'offer viewed')         6.3    9.0
# ('o_3', 'offer completed')      5.7    9.0
# ('o_10', 'offer viewed')        5.6    2.0
# ('o_9', 'offer viewed')         4.9    2.0
# total_trans                     4.5    1.0
# total_mean_amount               4.4    0.0
# ('o_6', 'offer viewed')         4.4    1.0
# gender_O                        4.1    1.0
# ('o_5', 'offer completed')      4.0    2.0
# ('o_6', 'offer received')      -3.9    1.0
# ('o_8', 'offer viewed')         3.7    1.0
# ('o_5', 'offer received')      -3.6    1.0
# ('o_10', 'offer received')     -3.6    1.0
# ('o_8', 'offer completed')      3.3    0.0
# ('o_3', 'offer viewed')         3.1    2.0
# ('o_10', 'transactions')        2.9    2.0
# ('o_9', 'transactions')         2.6    1.0
# ('o_2', 'offer received')      -2.3    0.0
# ('o_2', 'offer viewed')         2.3    1.0
# ('o_9', 'offer received')      -2.2    1.0
# np_mean_amount                 -1.9    1.0
# np_trans                       -1.7    0.0
# ('o_7', 'offer viewed')         1.5    2.0
# ('o_3', 'offer received')      -1.3    2.0
# ('o_2', 'transactions')        -1.0    1.0
# ('o_5', 'transactions')         1.0    0.0
# ('o_7', 'offer received')      -1.0    1.0
# gender_nan                      0.9    1.0
# completed_viewed               -0.9    2.0
# ('o_4', 'transactions')        -0.9    0.0
# np_amount                       0.9    1.0
# gender_M                        0.7    1.0
# ('o_8', 'offer received')      -0.5    1.0
# ('o_7', 'transactions')        -0.5    0.0
# ('o_8', 'transactions')         0.4    1.0
# ('o_6', 'transactions')         0.2    1.0
# ('o_1', 'transactions')        -0.2    0.0
# ('o_4', 'offer viewed')        -0.1    1.0
# ('o_4', 'offer received')      -0.1    1.0
# ('o_3', 'transactions')         0.1    1.0
# member_days                     0.0    0.0
# ('o_9', 'offer completed')      0.0    1.0
# ('o_10', 'offer completed')     0.0    1.0
# income                          0.0    3.0
# age                            -0.0    2.0

# %%
# define ElasticNetCV without normalization
model = ElasticNetCV(alphas=[0.05, 0.1, 0.2], copy_X=True, cv=5, eps=0.001, fit_intercept=True,
       l1_ratio=[0.2, 0.5, 0.7], max_iter=1000, n_alphas=None, n_jobs=-1)
# instantiate
elasticNetCV_simple = LinRegModel(profile, 'total_amount', model)
# perform linear regression modelling on instance
elasticNetCV_simple.go_quickDirty()
# output scores
elasticNetCV_simple
# Out:
# ElasticNetCV(alphas=[0.05, 0.1, 0.2], copy_X=True, cv=5, eps=0.001,
#        fit_intercept=True, l1_ratio=[0.2, 0.5, 0.7], max_iter=1000,
#        n_alphas=None, n_jobs=-1, normalize=False, positive=False,
#        precompute='auto', random_state=None, selection='cyclic',
#        tol=0.0001, verbose=0)
#
# RMSE on test data 39.07, r2-score 0.91.

# %%
print(model.alpha_)
print(model.l1_ratio_)
# Out:
# 0.05
# 0.7

# %%
# plot feature weights
# elasticNetCV_simple.print_coef_weights(n_bootstrap=10)

# %% [markdown]
# ## Second approach with proper data preparation

# %%
"""eliminate outliers"""

# count outliers
cleaning.count_outliers_IQR_method(profile, IQR_dist=1.5)
# Out:
# age
# Identified outliers: 48
# Percentage of outliers: 0.3%
#
# income
# Identified outliers: 306
# Percentage of outliers: 1.8%
#
# member_days
# Identified outliers: 287
# Percentage of outliers: 1.7%
#
# completed_viewed
# Identified outliers: 16
# Percentage of outliers: 0.1%
#
# total_trans
# Identified outliers: 296
# Percentage of outliers: 1.7%
#
# total_amount
# Identified outliers: 521
# Percentage of outliers: 3.1%
#
# total_mean_amount
# Identified outliers: 260
# Percentage of outliers: 1.5%
#
# np_trans
# Identified outliers: 330
# Percentage of outliers: 1.9%
#
# np_amount
# Identified outliers: 630
# Percentage of outliers: 3.7%
#
# np_mean_amount
# Identified outliers: 194
# Percentage of outliers: 1.1%
#
# prop_np_trans
# Identified outliers: 0
# Percentage of outliers: 0.0%
#
# prop_np_amount
# Identified outliers: 0
# Percentage of outliers: 0.0%
#
# ('o_1', 'offer received')
# Identified outliers: 122
# Percentage of outliers: 0.7%
#
# ('o_1', 'offer viewed')
# Identified outliers: 91
# Percentage of outliers: 0.5%
#
# ('o_1', 'offer completed')
# Identified outliers: 3147
# Percentage of outliers: 18.5%
#
# ('o_1', 'transactions')
# Identified outliers: 2993
# Percentage of outliers: 17.6%
#
# ('o_2', 'offer received')
# Identified outliers: 111
# Percentage of outliers: 0.7%
#
# ('o_2', 'offer viewed')
# Identified outliers: 92
# Percentage of outliers: 0.5%
#
# ('o_2', 'offer completed')
# Identified outliers: 2834
# Percentage of outliers: 16.7%
#
# ('o_2', 'transactions')
# Identified outliers: 2249
# Percentage of outliers: 13.2%
#
# ('o_3', 'offer received')
# Identified outliers: 128
# Percentage of outliers: 0.8%
#
# ('o_3', 'offer viewed')
# Identified outliers: 3616
# Percentage of outliers: 21.3%
#
# ('o_3', 'offer completed')
# Identified outliers: 3736
# Percentage of outliers: 22.0%
#
# ('o_3', 'transactions')
# Identified outliers: 2210
# Percentage of outliers: 13.0%
#
# ('o_4', 'offer received')
# Identified outliers: 125
# Percentage of outliers: 0.7%
#
# ('o_4', 'offer viewed')
# Identified outliers: 111
# Percentage of outliers: 0.7%
#
# ('o_4', 'offer completed')
# Identified outliers: 3665
# Percentage of outliers: 21.6%
#
# ('o_4', 'transactions')
# Identified outliers: 2150
# Percentage of outliers: 12.6%
#
# ('o_5', 'offer received')
# Identified outliers: 116
# Percentage of outliers: 0.7%
#
# ('o_5', 'offer viewed')
# Identified outliers: 2390
# Percentage of outliers: 14.1%
#
# ('o_5', 'offer completed')
# Identified outliers: 2950
# Percentage of outliers: 17.4%
#
# ('o_5', 'transactions')
# Identified outliers: 2856
# Percentage of outliers: 16.8%
#
# ('o_6', 'offer received')
# Identified outliers: 122
# Percentage of outliers: 0.7%
#
# ('o_6', 'offer viewed')
# Identified outliers: 108
# Percentage of outliers: 0.6%
#
# ('o_6', 'offer completed')
# Identified outliers: 61
# Percentage of outliers: 0.4%
#
# ('o_6', 'transactions')
# Identified outliers: 945
# Percentage of outliers: 5.6%
#
# ('o_7', 'offer received')
# Identified outliers: 110
# Percentage of outliers: 0.6%
#
# ('o_7', 'offer viewed')
# Identified outliers: 99
# Percentage of outliers: 0.6%
#
# ('o_7', 'offer completed')
# Identified outliers: 64
# Percentage of outliers: 0.4%
#
# ('o_7', 'transactions')
# Identified outliers: 1784
# Percentage of outliers: 10.5%
#
# ('o_8', 'offer received')
# Identified outliers: 126
# Percentage of outliers: 0.7%
#
# ('o_8', 'offer viewed')
# Identified outliers: 3554
# Percentage of outliers: 20.9%
#
# ('o_8', 'offer completed')
# Identified outliers: 3428
# Percentage of outliers: 20.2%
#
# ('o_8', 'transactions')
# Identified outliers: 2218
# Percentage of outliers: 13.0%
#
# ('o_9', 'offer received')
# Identified outliers: 117
# Percentage of outliers: 0.7%
#
# ('o_9', 'offer viewed')
# Identified outliers: 3303
# Percentage of outliers: 19.4%
#
# ('o_9', 'offer completed')
# Identified outliers: 0
# Percentage of outliers: 0.0%
#
# ('o_9', 'transactions')
# Identified outliers: 4075
# Percentage of outliers: 24.0%
#
# ('o_10', 'offer received')
# Identified outliers: 118
# Percentage of outliers: 0.7%
#
# ('o_10', 'offer viewed')
# Identified outliers: 73
# Percentage of outliers: 0.4%
#
# ('o_10', 'offer completed')
# Identified outliers: 0
# Percentage of outliers: 0.0%
#
# ('o_10', 'transactions')
# Identified outliers: 4022
# Percentage of outliers: 23.7%

# %%
# remove oultiers
outlier_cols = ['total_amount']
cleaning.remove_outliers_IQR_method(profile, outlier_cols=outlier_cols, IQR_dist=1.5)
# Out:
# total_amount
# Rows removed: 521
#
#
# Rows removed in total: 521

# %%
# instantiate
elasticNetCV_simple = LinRegModel(profile, 'total_amount', model)
# perform linear regression modelling on instance
elasticNetCV_simple.go_quickDirty()
# output scores
elasticNetCV_simple
# Out:
# ElasticNetCV(alphas=[0.05, 0.1, 0.2], copy_X=True, cv=5, eps=0.001,
#        fit_intercept=True, l1_ratio=[0.2, 0.5, 0.7], max_iter=1000,
#        n_alphas=None, n_jobs=-1, normalize=False, positive=False,
#        precompute='auto', random_state=None, selection='cyclic',
#        tol=0.0001, verbose=0)
#
# RMSE on test data 20.14, r2-score 0.93.

# %%
print(model.alpha_)
print(model.l1_ratio_)
# Out:
# 0.05
# 0.7

# %%
elasticNetCV_simple.print_coef_weights(n_bootstrap=10)
# Out:
#                              effect  error
# prop_np_amount                -20.1    0.0
# ('o_2', 'offer completed')      9.3    0.0
# ('o_1', 'offer completed')      8.1    0.0
# ('o_4', 'offer completed')      6.9    0.0
# ('o_7', 'offer completed')      5.8    0.0
# total_trans                     4.1    0.0
# ('o_5', 'offer viewed')         3.9    0.0
# ('o_6', 'offer completed')      3.8    0.0
# completed_viewed                3.5    0.0
# np_trans                       -3.4    1.0
# ('o_9', 'offer viewed')         3.4    1.0
# ('o_10', 'offer viewed')        3.0    1.0
# ('o_10', 'transactions')        2.8    1.0
# prop_np_trans                  -2.8    1.0
# ('o_9', 'transactions')         2.8    0.0
# ('o_1', 'offer received')      -2.7    0.0
# total_mean_amount               2.4    0.0
# ('o_3', 'offer completed')      2.3    1.0
# ('o_8', 'offer completed')      2.0    0.0
# ('o_5', 'offer completed')      1.9    0.0
# ('o_1', 'offer viewed')         1.9    0.0
# ('o_10', 'offer received')     -1.4    0.0
# ('o_3', 'offer viewed')         1.4    0.0
# ('o_5', 'offer received')      -1.2    0.0
# ('o_8', 'offer viewed')         1.2    0.0
# np_amount                       1.1    1.0
# ('o_4', 'transactions')        -1.0    0.0
# gender_O                        1.0    0.0
# ('o_7', 'transactions')        -0.8    0.0
# ('o_9', 'offer received')      -0.8    1.0
# ('o_2', 'transactions')        -0.7    0.0
# np_mean_amount                 -0.5    0.0
# ('o_5', 'transactions')         0.4    0.0
# ('o_8', 'transactions')         0.3    1.0
# ('o_2', 'offer received')      -0.3    0.0
# ('o_6', 'transactions')        -0.3    0.0
# ('o_1', 'transactions')        -0.2    0.0
# ('o_3', 'offer received')      -0.1    1.0
# ('o_10', 'offer completed')     0.0    0.0
# gender_M                       -0.0    0.0
# ('o_9', 'offer completed')      0.0    1.0
# age                            -0.0    1.0
# ('o_8', 'offer received')      -0.0    0.0
# ('o_7', 'offer viewed')         0.0    0.0
# ('o_7', 'offer received')      -0.0    0.0
# ('o_6', 'offer viewed')        -0.0    0.0
# ('o_6', 'offer received')      -0.0    0.0
# income                         -0.0    1.0
# ('o_4', 'offer viewed')         0.0    0.0
# ('o_4', 'offer received')       0.0    0.0
# ('o_3', 'transactions')        -0.0    0.0
# ('o_2', 'offer viewed')         0.0    0.0
# member_days                     0.0    1.0
# gender_nan                     -0.0    0.0

# %%
"""plot learning curves using 5-fold cross validation"""
elasticNetCV_simple.plot_learning_curves()
# Out:
# [learning_curve] Training set sizes: [  92  573 1053 1534 2015 2496 2977 3458 3938 4419 4900 5381 5862 6343
#  6823 7304 7785 8266 8747 9228]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    7.8s finished

# %%
"""log transform"""

# cleaning.apply_log10(profile, cols_to_log10=['member_days'])

# %%
# # define ElasticNetCV without normalization
# model = ElasticNetCV(alphas=[0.05], copy_X=True, cv=5, eps=0.001, fit_intercept=True,
#        l1_ratio=[0.2, 0.5, 0.7], max_iter=1000, n_alphas=None, n_jobs=-1)

# # instantiate
# elasticNetCV_simple = LinRegModel(profile, 'total_amount_log', model)
# # perform linear regression modelling on instance
# elasticNetCV_simple.go_quickDirty()
# # output scores
# elasticNetCV_simple
# Out:
# ElasticNetCV(alphas=[0.05], copy_X=True, cv=5, eps=0.001, fit_intercept=True,
#        l1_ratio=[0.2, 0.5, 0.7], max_iter=1000, n_alphas=None, n_jobs=-1,
#        normalize=False, positive=False, precompute='auto',
#        random_state=None, selection='cyclic', tol=0.0001, verbose=0)
#
# RMSE on test data 0.34, r2-score 0.65.

# %%
# check results
EDA.plot_num_hist(profile)
